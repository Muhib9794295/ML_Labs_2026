# %% [markdown]
# # Lab 13: Open-Ended Lab - CityLearn Solar Generation Forecasting (LSTM)
#
# **Student Name:** Muhib Ur Rehman
# **Registration Number:** 22JZELE0497
#
# ---
#
# ## 1. Problem Statement
#
# The objective is to develop a Long Short-Term Memory (LSTM) model to forecast **solar generation** using the CityLearn 2022 dataset. Accurate solar forecasting is critical for energy management and demand response in smart cities.
#
# ---

# %% [markdown]
# ## 2. Import Libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 3. Load Dataset

# %%
df = pd.read_csv(r'C:\Users\Muhib Ur-Rahman\Desktop\labs\Building_2.csv')   
print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (8760, 7)
#                   date  kg_CO2/kWh  Outdoor Drybulb Temperature [C]  \
# 0  2022-08-01 00:00:00    0.170724                             20.0
# 1  2022-08-01 01:00:00    0.157319                             20.1
# 2  2022-08-01 02:00:00    0.154503                             19.7
# 3  2022-08-01 03:00:00    0.150945                             19.3
# 4  2022-08-01 04:00:00    0.151820                             18.9
#
#    Relative Humidity [%]  Diffuse Solar Radiation [W/m2]  \
# 0                     84                               0
# 1                     79                               0
# 2                     78                               0
# 3                     78                               0
# 4                     78                               0
#
#    Direct Solar Radiation [W/m2]  Solar Generation [W/kW]
# 0                              0                      0.0
# 1                              0                      0.0
# 2                              0                      0.0
# 3                              0                      0.0
# 4                              0                      0.0

# %%
# Rename columns for easier use 
df.rename(columns={
    'date': 'timestamp',
    'Solar Generation [W/kW]': 'solar_generation'
}, inplace=True)

df['timestamp'] = pd.to_datetime(df['timestamp'])
df.set_index('timestamp', inplace=True)

# %% [markdown]
# ## 3. Data Exploration & Cleaning

# %%
print("Missing Values:\n", df.isnull().sum())
df.fillna(method='ffill', inplace=True)
# Out:
# Missing Values:
#  kg_CO2/kWh                         0
# Outdoor Drybulb Temperature [C]    0
# Relative Humidity [%]              0
# Diffuse Solar Radiation [W/m2]     0
# Direct Solar Radiation [W/m2]      0
# solar_generation                   0
# dtype: int64

# %%
print("\nBasic Statistics:")
print(df['solar_generation'].describe())
# Out:
# Basic Statistics:
# count    8760.000000
# mean      154.774259
# std       226.196434
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       301.411458
# max       786.083333
# Name: solar_generation, dtype: float64

# %% [markdown]
# ### Plot Solar Generation

# %%
plt.figure(figsize=(15,6))
plt.plot(df['solar_generation'][:1000])
plt.title('Solar Generation Over Time (First 1000 hours)')
plt.xlabel('Time')
plt.ylabel('Solar Generation (W/kW)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4. Feature Engineering

# %%
# Temporal Features
df['hour'] = df.index.hour
df['day_of_week'] = df.index.dayofweek
df['month'] = df.index.month
df['is_weekend'] = (df['day_of_week'] >= 5).astype(int)

# Lag Features
for lag in [1, 2, 3, 6, 12, 24]:
    df[f'solar_lag_{lag}'] = df['solar_generation'].shift(lag)

# Rolling Statistics
df['solar_roll_mean_24'] = df['solar_generation'].rolling(window=24).mean()
df['solar_roll_std_24'] = df['solar_generation'].rolling(window=24).std()

df.dropna(inplace=True)
print("Shape after feature engineering:", df.shape)
# Out:
# Shape after feature engineering: (8736, 18)

# %%
# Correlation with target
plt.figure(figsize=(10,8))
sns.heatmap(df.corr()[['solar_generation']].sort_values(by='solar_generation', ascending=False), 
            annot=True, cmap='coolwarm')
plt.title('Feature Correlation with Solar Generation')
plt.show()

# %% [markdown]
# ## 5. Prepare Data for LSTM

# %%
feature_columns = [col for col in df.columns if col != 'solar_generation']
X = df[feature_columns].values
y = df['solar_generation'].values.reshape(-1, 1)

# Scaling
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Create sequences
def create_sequences(X, y, time_steps=24):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:i+time_steps])
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys)

time_steps = 24
X_seq, y_seq = create_sequences(X_scaled, y_scaled, time_steps)

print("Sequence Shape:", X_seq.shape)
# Out:
# Sequence Shape: (8712, 24, 17)

# %%
# Train-Validation-Test Split (70% - 20% - 10%)
total_samples = len(X_seq)

train_size = int(total_samples * 0.70)
val_size = int(total_samples * 0.20)
test_size = total_samples - train_size - val_size

X_train = X_seq[:train_size]
X_val   = X_seq[train_size:train_size + val_size]
X_test  = X_seq[train_size + val_size:]

y_train = y_seq[:train_size]
y_val   = y_seq[train_size:train_size + val_size]
y_test  = y_seq[train_size + val_size:]

print("Train shape:", X_train.shape, y_train.shape)
print("Validation shape:", X_val.shape, y_val.shape)
print("Test shape:", X_test.shape, y_test.shape)
print(f"Total samples check: {train_size + val_size + test_size} = {total_samples}")
# Out:
# Train shape: (6098, 24, 17) (6098, 1)
# Validation shape: (1742, 24, 17) (1742, 1)
# Test shape: (872, 24, 17) (872, 1)
# Total samples check: 8712 = 8712

# %% [markdown]
# ## 6. Build & Train LSTM Model

# %%
model = Sequential([
    LSTM(64, activation='relu', input_shape=(time_steps, X_train.shape[2]), return_sequences=True),
    Dropout(0.2),
    LSTM(32, activation='relu'),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\Muhib Ur-Rahman\anaconda3\envs\dsp\lib\site-packages\keras\src\layers\rnn\lstm.py:148: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Muhib Ur-Rahman\anaconda3\envs\dsp\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 64)            20992
#
#  dropout (Dropout)           (None, 24, 64)            0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 33441 (130.63 KB)
# Trainable params: 33441 (130.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Callbacks
checkpoint = ModelCheckpoint('best_lstm_solar_model.h5', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),   
    epochs=25,
    batch_size=32,
    callbacks=[checkpoint, early_stop],
    verbose=1
)
# Out:
# Epoch 1/25
# WARNING:tensorflow:From c:\Users\Muhib Ur-Rahman\anaconda3\envs\dsp\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\Muhib Ur-Rahman\anaconda3\envs\dsp\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 191/191 [==============================] - ETA: 0s - loss: 0.0236 - mae: 0.1065
# Epoch 1: val_loss improved from inf to 0.02480, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 28s 51ms/step - loss: 0.0236 - mae: 0.1065 - val_loss: 0.0248 - val_mae: 0.0995
# Epoch 2/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0120 - mae: 0.0705
# Epoch 2: val_loss improved from 0.02480 to 0.01504, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 7s 35ms/step - loss: 0.0119 - mae: 0.0703 - val_loss: 0.0150 - val_mae: 0.0774
# Epoch 3/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0098 - mae: 0.0613
# Epoch 3: val_loss improved from 0.01504 to 0.01241, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 7s 36ms/step - loss: 0.0098 - mae: 0.0613 - val_loss: 0.0124 - val_mae: 0.0620
# Epoch 4/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0086 - mae: 0.0566
# Epoch 4: val_loss did not improve from 0.01241
# 191/191 [==============================] - 7s 37ms/step - loss: 0.0086 - mae: 0.0566 - val_loss: 0.0171 - val_mae: 0.0829
# Epoch 5/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0086 - mae: 0.0546
# Epoch 5: val_loss improved from 0.01241 to 0.01126, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 7s 35ms/step - loss: 0.0085 - mae: 0.0545 - val_loss: 0.0113 - val_mae: 0.0645
# Epoch 6/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0077 - mae: 0.0512
# Epoch 6: val_loss improved from 0.01126 to 0.00999, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 9s 49ms/step - loss: 0.0077 - mae: 0.0512 - val_loss: 0.0100 - val_mae: 0.0567
# Epoch 7/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0070 - mae: 0.0492
# Epoch 7: val_loss improved from 0.00999 to 0.00892, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 7s 36ms/step - loss: 0.0070 - mae: 0.0492 - val_loss: 0.0089 - val_mae: 0.0502
# Epoch 8/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0071 - mae: 0.0491
# Epoch 8: val_loss did not improve from 0.00892
# 191/191 [==============================] - 7s 35ms/step - loss: 0.0071 - mae: 0.0491 - val_loss: 0.0097 - val_mae: 0.0609
# Epoch 9/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0066 - mae: 0.0473
# Epoch 9: val_loss did not improve from 0.00892
# 191/191 [==============================] - 6s 33ms/step - loss: 0.0066 - mae: 0.0473 - val_loss: 0.0099 - val_mae: 0.0583
# Epoch 10/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0062 - mae: 0.0454
# Epoch 10: val_loss did not improve from 0.00892
# 191/191 [==============================] - 6s 34ms/step - loss: 0.0062 - mae: 0.0454 - val_loss: 0.0116 - val_mae: 0.0688
# Epoch 11/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0066 - mae: 0.0470
# Epoch 11: val_loss did not improve from 0.00892
# 191/191 [==============================] - 6s 33ms/step - loss: 0.0066 - mae: 0.0470 - val_loss: 0.0111 - val_mae: 0.0652
# Epoch 12/25
# 189/191 [============================>.] - ETA: 0s - loss: 0.0061 - mae: 0.0458
# Epoch 12: val_loss improved from 0.00892 to 0.00825, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 7s 35ms/step - loss: 0.0061 - mae: 0.0458 - val_loss: 0.0083 - val_mae: 0.0544
# Epoch 13/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0060 - mae: 0.0451
# Epoch 13: val_loss did not improve from 0.00825
# 191/191 [==============================] - 6s 34ms/step - loss: 0.0060 - mae: 0.0451 - val_loss: 0.0085 - val_mae: 0.0529
# Epoch 14/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0060 - mae: 0.0454
# Epoch 14: val_loss did not improve from 0.00825
# 191/191 [==============================] - 6s 33ms/step - loss: 0.0060 - mae: 0.0454 - val_loss: 0.0107 - val_mae: 0.0628
# Epoch 15/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0057 - mae: 0.0441
# Epoch 15: val_loss did not improve from 0.00825
# 191/191 [==============================] - 7s 35ms/step - loss: 0.0057 - mae: 0.0442 - val_loss: 0.0090 - val_mae: 0.0548
# Epoch 16/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0055 - mae: 0.0440
# Epoch 16: val_loss improved from 0.00825 to 0.00732, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 9s 46ms/step - loss: 0.0055 - mae: 0.0440 - val_loss: 0.0073 - val_mae: 0.0482
# Epoch 17/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0057 - mae: 0.0440
# Epoch 17: val_loss did not improve from 0.00732
# 191/191 [==============================] - 7s 39ms/step - loss: 0.0057 - mae: 0.0440 - val_loss: 0.0093 - val_mae: 0.0600
# Epoch 18/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0053 - mae: 0.0428
# Epoch 18: val_loss did not improve from 0.00732
# 191/191 [==============================] - 7s 35ms/step - loss: 0.0053 - mae: 0.0427 - val_loss: 0.0106 - val_mae: 0.0641
# Epoch 19/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0054 - mae: 0.0436
# Epoch 19: val_loss did not improve from 0.00732
# 191/191 [==============================] - 7s 35ms/step - loss: 0.0054 - mae: 0.0436 - val_loss: 0.0095 - val_mae: 0.0532
# Epoch 20/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0053 - mae: 0.0435
# Epoch 20: val_loss did not improve from 0.00732
# 191/191 [==============================] - 6s 34ms/step - loss: 0.0053 - mae: 0.0435 - val_loss: 0.0132 - val_mae: 0.0707
# Epoch 21/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0053 - mae: 0.0430
# Epoch 21: val_loss did not improve from 0.00732
# 191/191 [==============================] - 7s 35ms/step - loss: 0.0053 - mae: 0.0430 - val_loss: 0.0098 - val_mae: 0.0644
# Epoch 22/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0051 - mae: 0.0425
# Epoch 22: val_loss did not improve from 0.00732
# 191/191 [==============================] - 7s 35ms/step - loss: 0.0051 - mae: 0.0425 - val_loss: 0.0081 - val_mae: 0.0541
# Epoch 23/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0052 - mae: 0.0426
# Epoch 23: val_loss did not improve from 0.00732
# 191/191 [==============================] - 7s 35ms/step - loss: 0.0052 - mae: 0.0426 - val_loss: 0.0076 - val_mae: 0.0494
# Epoch 24/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0050 - mae: 0.0418
# Epoch 24: val_loss improved from 0.00732 to 0.00669, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 7s 34ms/step - loss: 0.0050 - mae: 0.0418 - val_loss: 0.0067 - val_mae: 0.0431
# Epoch 25/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0053 - mae: 0.0428
# Epoch 25: val_loss did not improve from 0.00669
# 191/191 [==============================] - 7s 36ms/step - loss: 0.0053 - mae: 0.0428 - val_loss: 0.0069 - val_mae: 0.0450

# %% [markdown]
# ## 7. Evaluation & Visualization

# %%
# Load best model
model = tf.keras.models.load_model(r'C:\Users\Muhib Ur-Rahman\Downloads\best_lstm_solar_model.h5')

# Predict
y_pred_scaled = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test)

# Metrics
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)

print(f"MAE: {mae:.2f} W/kW")
print(f"RMSE: {rmse:.2f} W/kW")
print(f"R² Score: {r2:.4f}")
# Out:
# 28/28 [==============================] - 1s 17ms/step
# MAE: 22.43 W/kW
# RMSE: 42.37 W/kW
# R² Score: 0.9738

# %%
# Plot Results
plt.figure(figsize=(15,6))
plt.plot(y_true[:500], label='Actual Solar Generation')
plt.plot(y_pred[:500], label='Predicted Solar Generation')
plt.title('Actual vs Predicted Solar Generation (Test Set)')
plt.xlabel('Time Steps')
plt.ylabel('Solar Generation (W/kW)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 8. Conclusion
#
# - Successfully developed an **LSTM-based model** for forecasting solar generation using the CityLearn 2022 dataset.
# - The model demonstrated strong predictive performance on the test set:
#   - **MAE:** 28.56 W/kW
#   - **RMSE:** 48.86 W/kW
#   - **R² Score:** 0.9652
#
# - The LSTM model effectively captured temporal dependencies and seasonal patterns in solar output, making it suitable for real-world energy forecasting appli optimization
#
# ---
#
# **Prepared by:** Muhib Ur Rehman (22JZELE0497)
